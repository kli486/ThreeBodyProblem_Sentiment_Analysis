# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyD3RQSXNrliXD9ciqiX9N60Etwr9rpeMLA"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="5lj99Uz1d50",
    maxResults=5000
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df
# Out:
#                      author          published_at            updated_at  \
# 0        @the-fantabulous-g  2023-12-16T04:21:56Z  2023-12-16T04:21:56Z
# 1                  @Edzyboy  2023-12-15T17:12:27Z  2023-12-15T17:12:27Z
# 2                @jhtrq1465  2023-12-15T14:27:09Z  2023-12-15T14:27:09Z
# 3      @SistoActivitatemAtm  2023-12-15T07:29:33Z  2023-12-15T07:29:33Z
# 4             @jeramahia123  2023-12-14T09:19:17Z  2023-12-14T09:19:17Z
# ..                      ...                   ...                   ...
# 95  @rafayetrahmanratul1059  2023-11-09T22:37:56Z  2023-11-09T22:37:56Z
# 96                   @Zaxjz  2023-11-09T18:21:55Z  2023-11-14T06:57:11Z
# 97           @MacLarenT1337  2023-11-09T15:56:49Z  2023-11-09T15:56:49Z
# 98         @ebrahimkhan9804  2023-11-09T14:23:05Z  2023-11-09T14:23:05Z
# 99                @SkodaZek  2023-11-09T03:09:26Z  2023-11-09T03:09:26Z
#
#     like_count                                               text
# ...

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyD3RQSXNrliXD9ciqiX9N60Etwr9rpeMLA"  

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

def fetch_replies(parent_id):
    replies = []
    request = youtube.comments().list(part="snippet",parentId=parent_id,maxResults=100)

    while request is not None:
        response = request.execute()
        for item in response['items']:
            comment = item['snippet']
            replies.append(comment['textDisplay'])

        request = youtube.comments().list_next(request, response)

    return replies

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append(comment['textDisplay'])
    
    # Fetch replies
    replies = fetch_replies(item['id'])
    comments.extend(replies)

video_id = "5lj99Uz1d50"  # Replace with the ID of the video you're interested in
comments = fetch_comments(video_id)

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])
print(len(df))
# Out:
# 2465

# %%
df.to_csv('YoutubeComment_Part1.csv')

# %%
import html

decoded_text = html.unescape("This isn&#39;t a test.")
print(decoded_text)  # Output: This isn't a test.
# Out:
# This isn't a test.

# %%
import html
import pandas as pd

# Assuming df is your DataFrame and 'text' is the column with HTML entities
df['text'] = df['text'].apply(html.unescape)

df.to_csv('YoutubeComment_Part1.csv')
